# %%
import pandas as pd

# %%
df=pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID         Order ID  Order Date   Ship Date  \
# 0           0   42433     AG-2011-2040  2011-01-01  2011-06-01
# 1           1   22253    IN-2011-47883  2011-01-01  2011-08-01
# 2           2   48883     HU-2011-1220  2011-01-01  2011-05-01
# 3           3   11731  IT-2011-3647632  2011-01-01  2011-05-01
# 4           4   22255    IN-2011-47883  2011-01-01  2011-08-01
#
#         Ship Mode Customer ID    Customer Name      Segment         City  ...  \
# 0  Standard Class    TB-11280  Toby Braunhardt     Consumer  Constantine  ...
# 1  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga  ...
# 2    Second Class      AT-735    Annie Thurman     Consumer     Budapest  ...
# 3    Second Class    EM-14140     Eugene Moren  Home Office    Stockholm  ...
# 4  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga  ...
#
#   Shipping Cost Order Priority  Per unit sale price Discount($)  \
# ...

# %%
columns=df.columns
columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State',
#        'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Per unit sale price',
#        'Discount($)', 'Per unit discount ($)', 'cost price',
#        'per unit cost price', 'profit %', 'year', 'Month'],
#       dtype='object')

# %%
sql_df =df.rename({'Row ID': 'Row_ID', 'Order ID': 'Order_ID','Order Date':'Order_Date','Ship Date':'Ship_Date',
                   'Ship Mode':'Ship_Mode','Customer ID':'Customer_ID','Customer Name':'Customer_Name','State':'States',
                   'Postal Code':'Postal_Code','Product ID':'Product_ID','Sub-Category':'Sub_Category',
                   'Product Name':'Product_Name','Shipping Cost':'Shipping_Cost','Order Priority':'Order_Priority',
                   'Per unit sale price':'Per_unit_sale_price','Discount($)':'Discount_dollars',
                   'Per unit discount ($)':'Per_unit_discount_dollars','cost price':'cost_price',
                   'per unit cost price':'per_unit_cost_price',
                   'profit %':'profit_percentage','year':'years','Month':'Months'}, axis='columns')

# %%
sql_df.head()
# Out:
#    Unnamed: 0  Row_ID         Order_ID  Order_Date   Ship_Date  \
# 0           0   42433     AG-2011-2040  2011-01-01  2011-06-01
# 1           1   22253    IN-2011-47883  2011-01-01  2011-08-01
# 2           2   48883     HU-2011-1220  2011-01-01  2011-05-01
# 3           3   11731  IT-2011-3647632  2011-01-01  2011-05-01
# 4           4   22255    IN-2011-47883  2011-01-01  2011-08-01
#
#         Ship_Mode Customer_ID    Customer_Name      Segment         City  ...  \
# 0  Standard Class    TB-11280  Toby Braunhardt     Consumer  Constantine  ...
# 1  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga  ...
# 2    Second Class      AT-735    Annie Thurman     Consumer     Budapest  ...
# 3    Second Class    EM-14140     Eugene Moren  Home Office    Stockholm  ...
# 4  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga  ...
#
#   Shipping_Cost Order_Priority  Per_unit_sale_price Discount_dollars  \
# ...

# %%
sql_df.columns
# Out:
# Index(['Unnamed: 0', 'Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date',
#        'Ship_Mode', 'Customer_ID', 'Customer_Name', 'Segment', 'City',
#        'States', 'Country', 'Postal_Code', 'Market', 'Region', 'Product_ID',
#        'Category', 'Sub_Category', 'Product_Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping_Cost', 'Order_Priority',
#        'Per_unit_sale_price', 'Discount_dollars', 'Per_unit_discount_dollars',
#        'cost_price', 'per_unit_cost_price', 'profit_percentage', 'years',
#        'Months'],
#       dtype='object')

# %%
#order table

Order=sql_df[["Order_ID","Row_ID","Order_Date","Product_Name","cost_price",'Quantity',"Sales","Discount_dollars"]]
Order.head()
Order.to_csv("Order.csv")

# %%
#Product table
Product=sql_df[["Order_ID","Product_ID","Category","Sub_Category","Segment"]]
Product.head()
Product.to_csv("Product.csv")

# %%
#Shipping_info

Shipping_info=sql_df[["Order_ID","City","States","Country","Shipping_Cost",'Order_Priority']]
Shipping_info.head()
Shipping_info.to_csv("Shipping_info.csv")

# %%
#Customer table

Customer=sql_df[["Product_ID","Customer_Name","Segment"]]
Customer.head()
Customer.to_csv("Customer.csv")
